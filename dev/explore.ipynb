# %%
from pathlib import Path
import pandas as pd
import seaborn as sns

datafile  = Path("../data/processed/data.csv")
df = pd.read_csv(datafile)

# %%
df.head()
# Out:
#        Country   Region C/T  Edition Status  PR rating  CL rating  A1  A2  A3  \
# 0     Abkhazia  Eurasia   t     2024     PF          5          5   2   2   1
# 1  Afghanistan     Asia   c     2024     NF          7          7   0   0   0
# 2      Albania   Europe   c     2024     PF          3          3   3   3   3
# 3      Algeria   Africa   c     2024     NF          6          5   1   1   1
# 4      Andorra   Europe   c     2024      F          1          1   4   4   4
#
#    ...   F  G1  G2  G3  G4   G  CL  Total   latitude  longitude
# 0  ...   4   1   1   2   1   5  22     39        NaN        NaN
# 1  ...   0   0   1   0   1   2   5      6  25.067203  55.307090
# 2  ...  10   3   2   2   2   9  40     68        NaN        NaN
# 3  ...   6   2   2   2   1   7  22     32  36.801039   3.042593
# 4  ...  15   4   4   3   4  15  55     93  42.508860   1.531227
#
# [5 rows x 46 columns]

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
#
# File ~/Downloads/informative_website/.venv/lib/python3.11/site-packages/pandas/core/frame.py:11036, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11034 cols = data.columns
#   11035 idx = cols.copy()
# > 11036 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11038 if method == "pearson":
#   11039     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Downloads/informative_website/.venv/lib/python3.11/site-packages/pandas/core/frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1982 if result.dtype is not dtype:
#    1983     result = np.array(result, dtype=dtype, copy=False)
#
# File ~/Downloads/informative_website/.venv/lib/python3.11/site-packages/pandas/core/internals/managers.py:1692, in BlockManager.as_array(self, dtype, copy, na_value)
#    1690         arr.flags.writeable = False
#    1691 else:
# -> 1692     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1693     # The underlying data was copied within _interleave, so no need
#    1694     # to further copy if copy=True or setting na_value
#    1696 if na_value is lib.no_default:
#
# File ~/Downloads/informative_website/.venv/lib/python3.11/site-packages/pandas/core/internals/managers.py:1751, in BlockManager._interleave(self, dtype, na_value)
#    1749     else:
#    1750         arr = blk.get_values(dtype)
# -> 1751     result[rl.indexer] = arr
#    1752     itemmask[rl.indexer] = 1
#    1754 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Abkhazia'

# %%
print(df.head())





sns.histplot(df['column_name'])

sns.boxplot(x='column_name', data=df)

# Show the plots
plt.show()
# Out:
#        Country   Region C/T  Edition Status  PR rating  CL rating  A1  A2  A3  \
# 0     Abkhazia  Eurasia   t     2024     PF          5          5   2   2   1
# 1  Afghanistan     Asia   c     2024     NF          7          7   0   0   0
# 2      Albania   Europe   c     2024     PF          3          3   3   3   3
# 3      Algeria   Africa   c     2024     NF          6          5   1   1   1
# 4      Andorra   Europe   c     2024      F          1          1   4   4   4
#
#    ...   F  G1  G2  G3  G4   G  CL  Total   latitude  longitude
# 0  ...   4   1   1   2   1   5  22     39        NaN        NaN
# 1  ...   0   0   1   0   1   2   5      6  25.067203  55.307090
# 2  ...  10   3   2   2   2   9  40     68        NaN        NaN
# 3  ...   6   2   2   2   1   7  22     32  36.801039   3.042593
# 4  ...  15   4   4   3   4  15  55     93  42.508860   1.531227
#
# [5 rows x 46 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 print(df.head())
# ----> 4 sns.pairplot(df)
#       7 sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
#      10 sns.histplot(df['column_name'])
#
# File ~/Downloads/informative_website/.venv/lib/python3.11/site-packages/seaborn/axisgrid.py:2119, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2117 # Set up the PairGrid
#    2118 grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2119 grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2120                 hue_order=hue_order, palette=palette, corner=corner,
#    2121                 height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2123 # Add the markers here as PairGrid has figured out how many levels of the
#    2124 # hue variable are needed and we don't want to duplicate that process
#    2125 if markers is not None:
#
# File ~/Downloads/informative_website/.venv/lib/python3.11/site-packages/seaborn/axisgrid.py:1354, in PairGrid.__init__(self, data, hue, vars, x_vars, y_vars, hue_order, palette, hue_kws, corner, diag_sharey, height, aspect, layout_pad, despine, dropna)
#    1352 if ax is None:
#    1353     continue
# -> 1354 for label in ax.get_yticklabels():
#    1355     label.set_visible(False)
#    1356 ax.yaxis.offsetText.set_visible(False)
#
# File ~/Downloads/informative_website/.venv/lib/python3.11/site-packages/matplotlib/axes/_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File ~/Downloads/informative_website/.venv/lib/python3.11/site-packages/matplotlib/axis.py:1467, in Axis.get_ticklabels(self, minor, which)
#    1465 if minor:
#    1466     return self.get_minorticklabels()
# -> 1467 return self.get_majorticklabels()
#
# File ~/Downloads/informative_website/.venv/lib/python3.11/site-packages/matplotlib/axis.py:1424, in Axis.get_majorticklabels(self)
#    1422 def get_majorticklabels(self):
#    1423     """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1424     self._update_ticks()
#    1425     ticks = self.get_major_ticks()
#    1426     labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#
# File ~/Downloads/informative_website/.venv/lib/python3.11/site-packages/matplotlib/axis.py:1277, in Axis._update_ticks(self)
#    1275 major_locs = self.get_majorticklocs()
#    1276 major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1277 major_ticks = self.get_major_ticks(len(major_locs))
#    1278 for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#    1279     tick.update_position(loc)
#
# File ~/Downloads/informative_website/.venv/lib/python3.11/site-packages/matplotlib/axis.py:1628, in Axis.get_major_ticks(self, numticks)
#    1626     tick = self._get_tick(major=True)
#    1627     self.majorTicks.append(tick)
# -> 1628     self._copy_tick_props(self.majorTicks[0], tick)
#    1630 return self.majorTicks[:numticks]
#
# File ~/Downloads/informative_website/.venv/lib/python3.11/site-packages/matplotlib/axis.py:1584, in Axis._copy_tick_props(self, src, dest)
#    1582 dest.tick1line.update_from(src.tick1line)
#    1583 dest.tick2line.update_from(src.tick2line)
# -> 1584 dest.gridline.update_from(src.gridline)
#
# File ~/Downloads/informative_website/.venv/lib/python3.11/site-packages/matplotlib/lines.py:1356, in Line2D.update_from(self, other)
#    1353 self._solidjoinstyle = other._solidjoinstyle
#    1355 self._linestyle = other._linestyle
# -> 1356 self._marker = MarkerStyle(marker=other._marker)
#    1357 self._drawstyle = other._drawstyle
#
# File ~/Downloads/informative_website/.venv/lib/python3.11/site-packages/matplotlib/markers.py:255, in MarkerStyle.__init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     253 self._user_joinstyle = JoinStyle(joinstyle) if joinstyle is not None else None
#     254 self._set_fillstyle(fillstyle)
# --> 255 self._set_marker(marker)
#
# File ~/Downloads/informative_website/.venv/lib/python3.11/site-packages/matplotlib/markers.py:332, in MarkerStyle._set_marker(self, marker)
#     330     self._marker_function = self._set_tuple_marker
#     331 elif isinstance(marker, MarkerStyle):
# --> 332     self.__dict__ = copy.deepcopy(marker.__dict__)
#     333 else:
#     334     try:
#
# File ~/anaconda3/lib/python3.11/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/anaconda3/lib/python3.11/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File ~/anaconda3/lib/python3.11/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/anaconda3/lib/python3.11/copy.py:259, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     255     except KeyError:
#     256         # aha, this is the first one :-)
#     257         memo[id(memo)]=[x]
# --> 259 def _reconstruct(x, memo, func, args,
#     260                  state=None, listiter=None, dictiter=None,
#     261                  *, deepcopy=deepcopy):
#     262     deep = memo is not None
#     263     if deep and args:
#
# KeyboardInterrupt:
